# %%
# Libreria para cargar nuestro drive
from google.colab import drive
# Cargamos nuestro drive en nuestro notebook
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive/Documentos/UADY/Semestre 11/CAV/Tarea1"
# Out:
# Colab_Erick_Casanova.ipynb  idlePython_Erick_Casanova.py
# datos			    Jupyter_Erick_Casanova.ipynb
# figuras

# %% [markdown]
# # Ejemplo de notebook Jupyter

# %% [markdown]
# ## Cargando librerías

# %%
# Cargar las biblioteca Pandas con el alias 'pd’
# Cargar las biblioteca Matplotlib con el alias ‘plt’
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Se analizará la gráfica de la cronología de la producción global de pástico
# *Fuente:* https://ourworldindata.org/grapher/global-plastics-production
# ![Imagen de producción global de plástico](https://docs.google.com/uc?export=download&id=1gEG6XuVMWls0lmwWqIdVNqZZU1UAUI4j)

# %%
# Leer datos del archivo datos.csv
data = pd.read_csv ("/content/drive/My Drive/Documentos/UADY/Semestre 11/CAV/Tarea1/datos/global-plastics-production.csv")

# %%
# Vista previa de las primeras 5 lineas de los datos cargados
print(data.head ())
# Out:
#    Year  Global plastics production (million tonnes)
# 0  1950                                            2
# 1  1951                                            2
# 2  1952                                            2
# 3  1953                                            3
# 4  1954                                            3

# %% [markdown]
# ## Graficando los datos

# %%
#Graficamos las variables
data.plot(x ='Year', y = 'Global plastics production (million tonnes)', kind = 'line')
plt.show()
