# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/banner_sdc.png">

# %% [markdown]
# <center><h1 style="font-size:2em;color:#2467C0"> Semáforos verdes
#  </h1></center>
# <br>
# <table>
# <col width="650">
# <col width="350">
# <tr>
# <td><img src="figuras/semaforos_verdes.png" align="middle" style="width:850px;"/></td>
# <td>
#
#
# **Objetivo:**
#
#
# Encontrar la señal verde de los semáforos
#
# <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Cargar librerias

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2 as cv

# %%
img0 = cv.imread('figuras/semaforo.jpg')
img0 = cv.cvtColor(img0, cv.COLOR_BGR2RGB)

img1 = cv.imread('figuras/semaforo_verde_1.jpg')
img1 = cv.cvtColor(img1, cv.COLOR_BGR2RGB)

img2 = cv.imread('figuras/semaforo_verde_2.jpg')
img2 = cv.cvtColor(img2, cv.COLOR_BGR2RGB)

img3 = cv.imread('figuras/semaforo_verde_3.jpg')
img3 = cv.cvtColor(img3, cv.COLOR_BGR2RGB)

img4 = cv.imread('figuras/semaforo_verde_4.jpg')
img4 = cv.cvtColor(img4, cv.COLOR_BGR2RGB)

#Imprimiendo las imagenes

plt.figure(figsize=(10,6))

plt.subplot(231)
plt.imshow(img0)

plt.subplot(232)
plt.imshow(img1)

plt.subplot(233)
plt.imshow(img2)

plt.subplot(234)
plt.imshow(img3)

plt.subplot(235)
plt.imshow(img4)

plt.show()

# %% [markdown]
# # Definiendo funciones para encontrar circulos verdes

# %%
d = {'Imagen': [], 
     'pixel_value/n': [],
     'Pass': []}
total_circles = pd.DataFrame(d)

# %%
def hsv_convert(image):
    return cv.cvtColor(image, cv.COLOR_BGR2HSV)

# %%
#definimos una función que retorne la mascara para el color verde
def green_finder(image):
    lower_green = np.array([39,50,83]) #83
    upper_green = np.array([91,255,255])
    img_hsv = hsv_convert(image)
    mask_green = cv.inRange(img_hsv, lower_green, upper_green)
    return mask_green

# %%
def circle_finder(img):
    #print('in circle_finder, circles found')
    circles = cv.HoughCircles(img, cv.HOUGH_GRADIENT, 1, 30, param1 = 50, param2 = 5, minRadius = 0, maxRadius = 30)
    #print(circles)
    return circles

# %%
def circle_writer(original_image, name):

    #counter solo sirve para ver cuantos circulos pasaron la prueba
    counter = 0
    circle_name = []
    circle_values = []
    circle_logical = []
    global total_circles
        
    print('-----------------------------------------')
    
    #Encontrar la mascara
    img_green_mask = green_finder(original_image)
    
    #Estética de escritura
    font = cv.FONT_HERSHEY_SIMPLEX
    region = 5
    
    #Circulos
    green_circles = circle_finder(img_green_mask)

    #Entra si existe un circulo
    if green_circles is not None:
        green_circles = np.uint16(np.around(green_circles))
        
        #Para cada circulo
        for i in green_circles[0, :]:
            pixel_value = 0.0
            n = 0.0
            check = False
            
            for j in range(-region, region):
                for k in range(-region, region):
                    pixel_value += img_green_mask[i[1]+j, i[0]+k]
                    n += 1

            
            if pixel_value/n > 50:
                cv.circle(original_image, (i[0], i[1]), i[2]+10, (0,255,0), 2)
                cv.putText(original_image, 'Verde', (i[0]-i[2], i[1]-i[2]-10), font, 1, (0, 255, 0), 2, cv.LINE_AA)
                counter += 1
                check = True
                
            #Llenando los arrays
            circle_name.append(name)
            circle_values.append(pixel_value/n)
            circle_logical.append(check)
    
    data = {'Imagen': circle_name, 
            'pixel_value/n': circle_values, 
            'Pass': circle_logical}
    
    circulos = pd.DataFrame(data)
    print(circulos)
    total_circles = pd.concat([total_circles, circulos], ignore_index=True)
    
    print('***** Valor mínimo:', circulos[circulos['Pass'] == True]['pixel_value/n'].min())
    

    return cv.cvtColor(original_image, cv.COLOR_BGR2RGB)

# %% [markdown]
# # Analizando imagenes

# %%
#Definiendo imagenes
img0 = cv.imread('figuras/semaforo.jpg')
img1 = cv.imread('figuras/semaforo_verde_1.jpg')
img2 = cv.imread('figuras/semaforo_verde_2.jpg')
img3 = cv.imread('figuras/semaforo_verde_3.jpg')
img4 = cv.imread('figuras/semaforo_verde_4.jpg')
img5 = cv.imread('figuras/semaforo_verde_5.jpg')
img6 = cv.imread('figuras/semaforo_verde_6.jpg')
img7 = cv.imread('figuras/semaforo_verde_7.jpg')
img8 = cv.imread('figuras/semaforo_verde_8.jpg')
img9 = cv.imread('figuras/semaforo_verde_9.jpg')

# %%
#Encontrando y dibujando circulos para cada imagen
img0 = circle_writer(img0, 'img0')
img1 = circle_writer(img1, 'img1')
img2 = circle_writer(img2, 'img2')
img3 = circle_writer(img3, 'img3')
img4 = circle_writer(img4, 'img4')
img5 = circle_writer(img5, 'img5')
img6 = circle_writer(img6, 'img6')
img7 = circle_writer(img7, 'img7')
img8 = circle_writer(img8, 'img8')
img9 = circle_writer(img9, 'img9')
# Out:
# -----------------------------------------
#    Imagen  pixel_value/n   Pass
# 0    img0         255.00   True
# 1    img0         255.00   True
# 2    img0         255.00   True
# 3    img0         255.00   True
# 4    img0         255.00   True
# 5    img0         255.00   True
# 6    img0         198.90   True
# 7    img0         255.00   True
# 8    img0         255.00   True
# 9    img0         255.00   True
# 10   img0           0.00  False
# 11   img0          17.85  False
# ***** Valor mínimo: 198.9
# -----------------------------------------
#   Imagen  pixel_value/n  Pass
# 0   img1          255.0  True
# 1   img1          255.0  True
# ***** Valor mínimo: 255.0
# -----------------------------------------
#   Imagen  pixel_value/n   Pass
# 0   img2          255.0   True
# 1   img2            0.0  False
# 2   img2            5.1  False
# 3   img2            0.0  False
# ***** Valor mínimo: 255.0
# -----------------------------------------
#   Imagen  pixel_value/n   Pass
# 0   img3         206.55   True
# 1   img3           0.00  False
# 2   img3          61.20   True
# ***** Valor mínimo: 61.2
# -----------------------------------------
#   Imagen  pixel_value/n   Pass
# 0   img4          255.0   True
# 1   img4           25.5  False
# 2   img4           91.8   True
# 3   img4            5.1  False
# ***** Valor mínimo: 91.8
# -----------------------------------------
#    Imagen  pixel_value/n   Pass
# 0    img5         252.45   True
# 1    img5         249.90   True
# 2    img5         255.00   True
# 3    img5         226.95   True
# 4    img5         247.35   True
# 5    img5         242.25   True
# 6    img5         249.90   True
# 7    img5           0.00  False
# 8    img5         255.00   True
# 9    img5         229.50   True
# 10   img5         255.00   True
# 11   img5         255.00   True
# 12   img5           0.00  False
# 13   img5         255.00   True
# 14   img5           0.00  False
# 15   img5         255.00   True
# 16   img5         255.00   True
# 17   img5           0.00  False
# 18   img5           0.00  False
# 19   img5         255.00   True
# 20   img5           0.00  False
# 21   img5           0.00  False
# 22   img5           0.00  False
# 23   img5           0.00  False
# 24   img5         255.00   True
# 25   img5         255.00   True
# 26   img5           5.10  False
# 27   img5           0.00  False
# 28   img5          12.75  False
# 29   img5           0.00  False
# 30   img5           0.00  False
# 31   img5         252.45   True
# 32   img5           0.00  False
# 33   img5         255.00   True
# 34   img5         242.25   True
# 35   img5           0.00  False
# 36   img5           0.00  False
# 37   img5         255.00   True
# 38   img5           0.00  False
# 39   img5           2.55  False
# 40   img5           0.00  False
# 41   img5           0.00  False
# 42   img5          10.20  False
# 43   img5         255.00   True
# 44   img5           0.00  False
# 45   img5           0.00  False
# 46   img5         255.00   True
# 47   img5         224.40   True
# 48   img5           0.00  False
# 49   img5           0.00  False
# 50   img5         252.45   True
# 51   img5           0.00  False
# 52   img5         234.60   True
# 53   img5           0.00  False
# 54   img5           0.00  False
# 55   img5         255.00   True
# 56   img5         255.00   True
# 57   img5           0.00  False
# ***** Valor mínimo: 224.4
# -----------------------------------------
#    Imagen  pixel_value/n   Pass
# 0    img6         255.00   True
# 1    img6         255.00   True
# 2    img6           0.00  False
# 3    img6         255.00   True
# 4    img6          15.30  False
# 5    img6           0.00  False
# 6    img6           0.00  False
# 7    img6          63.75   True
# 8    img6         255.00   True
# 9    img6          48.45  False
# 10   img6           0.00  False
# 11   img6           0.00  False
# 12   img6           5.10  False
# 13   img6          12.75  False
# 14   img6          10.20  False
# 15   img6         173.40   True
# ***** Valor mínimo: 63.75
# -----------------------------------------
#    Imagen  pixel_value/n   Pass
# 0    img7          84.15   True
# 1    img7           0.00  False
# 2    img7         206.55   True
# 3    img7           0.00  False
# 4    img7           0.00  False
# 5    img7           0.00  False
# 6    img7           2.55  False
# 7    img7          12.75  False
# 8    img7          15.30  False
# 9    img7           5.10  False
# 10   img7          20.40  False
# 11   img7           0.00  False
# 12   img7           0.00  False
# 13   img7          22.95  False
# 14   img7           0.00  False
# ***** Valor mínimo: 84.15
# -----------------------------------------
#   Imagen  pixel_value/n  Pass
# 0   img8         237.15  True
# ***** Valor mínimo: 237.15
# -----------------------------------------
#   Imagen  pixel_value/n   Pass
# 0   img9          255.0   True
# 1   img9            0.0  False
# 2   img9            0.0  False
# 3   img9            0.0  False
# 4   img9            0.0  False
# ***** Valor mínimo: 255.0

# %% [markdown]
# # Analisis de datos para elegir pixel_value/n

# %%
total_circles[total_circles['Pass'] == True]
# Out:
#     Imagen  pixel_value/n  Pass
# 0     img0         255.00   1.0
# 1     img0         255.00   1.0
# 2     img0         255.00   1.0
# 3     img0         255.00   1.0
# 4     img0         255.00   1.0
# 5     img0         255.00   1.0
# 6     img0         198.90   1.0
# 7     img0         255.00   1.0
# 8     img0         255.00   1.0
# 9     img0         255.00   1.0
# 12    img1         255.00   1.0
# 13    img1         255.00   1.0
# 14    img2         255.00   1.0
# 18    img3         206.55   1.0
# 20    img3          61.20   1.0
# 21    img4         255.00   1.0
# 23    img4          91.80   1.0
# 25    img5         252.45   1.0
# 26    img5         249.90   1.0
# 27    img5         255.00   1.0
# 28    img5         226.95   1.0
# 29    img5         247.35   1.0
# 30    img5         242.25   1.0
# 31    img5         249.90   1.0
# 33    img5         255.00   1.0
# 34    img5         229.50   1.0
# 35    img5         255.00   1.0
# 36    img5         255.00   1.0
# 38    img5         255.00   1.0
# 40    img5         255.00   1.0
# 41    img5         255.00   1.0
# 44    img5         255.00   1.0
# 49    img5         255.00   1.0
# 50    img5         255.00   1.0
# 56    img5         252.45   1.0
# 58    img5         255.00   1.0
# 59    img5         242.25   1.0
# 62    img5         255.00   1.0
# 68    img5         255.00   1.0
# 71    img5         255.00   1.0
# 72    img5         224.40   1.0
# 75    img5         252.45   1.0
# 77    img5         234.60   1.0
# 80    img5         255.00   1.0
# 81    img5         255.00   1.0
# 83    img6         255.00   1.0
# 84    img6         255.00   1.0
# 86    img6         255.00   1.0
# 90    img6          63.75   1.0
# 91    img6         255.00   1.0
# 98    img6         173.40   1.0
# 99    img7          84.15   1.0
# 101   img7         206.55   1.0
# 114   img8         237.15   1.0
# 115   img9         255.00   1.0

# %%
small = total_circles[total_circles['Pass'] == True]['pixel_value/n'].min()
print('Imagen con el número de pixel_value/n más pequeño')
print(total_circles[total_circles['pixel_value/n'] == min]['Imagen'])
print('Valor:', small)
# Out:
# Imagen con el número de pixel_value/n más pequeño
# Series([], Name: Imagen, dtype: object)
# Valor: 61.2

# %% [markdown]
# # Vista de imagenes

# %%
plt.figure(figsize=(30, 30))

plt.subplot(321)
plt.imshow(img0)
plt.title("img0")


plt.subplot(322)
plt.imshow(img1)
plt.title("img1")


plt.subplot(323)
plt.imshow(img2)
plt.title("img2")


plt.subplot(324)
plt.imshow(img3)
plt.title("img3")


plt.subplot(325)
plt.imshow(img4)
plt.title("img4")


plt.show()

plt.figure(figsize=(30, 30))

plt.subplot(321)
plt.imshow(img5)
plt.title("img5")


plt.subplot(322)
plt.imshow(img6)
plt.title("img6")


plt.subplot(323)
plt.imshow(img7)
plt.title("img7")


plt.subplot(324)
plt.imshow(img8)
plt.title("img8")


plt.subplot(325)
plt.imshow(img9)
plt.title("img9")


plt.show()

# %%
plt.imshow(img7)
